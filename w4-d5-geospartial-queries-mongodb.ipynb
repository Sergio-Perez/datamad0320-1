# %% [markdown]
# # Geocoding

# %%
import requests

def geocode(address):
    '''
    Use geocode api to do forward geocoding. https://geocode.xyz/api
    '''
    res = requests.get(f"https://geocode.xyz/{address}",params={"json":1})
    data = res.json()
    print(res)
    # Return as GeoJSON -> https://geojson.org/
    return {
        "type":"Point",
        "coordinates": [float(data["longt"]), float(data["latt"])]
    }

# %%
ironhack = "Paseo de la chopera 14 Madrid"
geocode(ironhack)
# Out:
# {'type': 'Point', 'coordinates': [-3.7011, 40.39652]}

# %% [markdown]
# # Mongodb Geoqueries

# %% [markdown]
# ## Preparing data...

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost/datamad0320")
db = client.get_database()

# %%
fb = db.companies.find_one({"name":"Facebook"},{"offices":1})

# %%
import pandas as pd

pd.DataFrame(fb["offices"])
# Out:
#     description          address1 address2 zip_code        city state_code  \
# 0  Headquarters  1601 Willow Road             94025  Menlo Park         CA
# 1     Europe HQ                                          Dublin       None
# 2      New York   340 Madison Ave             10017    New York         NY
#
#   country_code   latitude   longitude
# 0          USA  37.416050 -122.151801
# 1          IRL  53.344104   -6.267494
# 2          USA  40.755716  -73.979247

# %%
all_offices = list(db.companies.find({},{"offices":1,"name":1,"category_code":1}))

# %%
companydata = pd.DataFrame(all_offices)
companydata
# Out:
#                             _id                 name    category_code  \
# 0      52cdef7c4bab8bd675297d8b            AdventNet       enterprise
# 1      52cdef7c4bab8bd675297d8d                 Digg             news
# 2      52cdef7c4bab8bd675297d8c                 Zoho         software
# 3      52cdef7c4bab8bd675297d8a             Wetpaint              web
# 4      52cdef7c4bab8bd675297d8f            Omnidrive  network_hosting
# ...                         ...                  ...              ...
# 18796  52cdef7f4bab8bd67529c6f5               Oriact         software
# 18797  52cdef7f4bab8bd67529c6f8          goBookmaker              web
# 18798  52cdef7f4bab8bd67529c6f7           AfterLogic         software
# 18799  52cdef7f4bab8bd67529c6f9  EnteGreat Solutions         software
# 18800  52cdef7f4bab8bd67529c6fa            EnteGreat       enterprise
#
#                                                  offices
# 0      [{'description': 'Headquarters', 'address1': '...
# 1      [{'description': None, 'address1': '135 Missis...
# 2      [{'description': 'Headquarters', 'address1': '...
# 3      [{'description': '', 'address1': '710 - 2nd Av...
# 4      [{'description': '', 'address1': 'Suite 200', ...
# ...                                                  ...
# 18796  [{'description': '', 'address1': 'LÃ¤rchenweg ...
# 18797                                                 []
# 18798  [{'description': 'Livingston', 'address1': 'P....
# 18799  [{'description': '', 'address1': '', 'address2...
# 18800  [{'description': '', 'address1': '1900 Interna...
#
# [18801 rows x 4 columns]

# %%
companydata = companydata.explode("offices")
companydata
# Out:
#                             _id                 name category_code  \
# 0      52cdef7c4bab8bd675297d8b            AdventNet    enterprise
# 1      52cdef7c4bab8bd675297d8d                 Digg          news
# 2      52cdef7c4bab8bd675297d8c                 Zoho      software
# 3      52cdef7c4bab8bd675297d8a             Wetpaint           web
# 3      52cdef7c4bab8bd675297d8a             Wetpaint           web
# ...                         ...                  ...           ...
# 18796  52cdef7f4bab8bd67529c6f5               Oriact      software
# 18797  52cdef7f4bab8bd67529c6f8          goBookmaker           web
# 18798  52cdef7f4bab8bd67529c6f7           AfterLogic      software
# 18799  52cdef7f4bab8bd67529c6f9  EnteGreat Solutions      software
# 18800  52cdef7f4bab8bd67529c6fa            EnteGreat    enterprise
#
#                                                  offices
# 0      {'description': 'Headquarters', 'address1': '4...
# 1      {'description': None, 'address1': '135 Mississ...
# 2      {'description': 'Headquarters', 'address1': '4...
# 3      {'description': '', 'address1': '710 - 2nd Ave...
# 3      {'description': '', 'address1': '270 Lafayette...
# ...                                                  ...
# 18796  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 18797                                                NaN
# 18798  {'description': 'Livingston', 'address1': 'P.O...
# 18799  {'description': '', 'address1': '', 'address2'...
# 18800  {'description': '', 'address1': '1900 Internat...
#
# [21762 rows x 4 columns]

# %%
# transform office object into GeoPoint for office
def officeToGeoPoint(row):
    office = row.offices
    if type(office) == dict:
        if 'latitude' in office and 'longitude' in office:
            if(type(office["latitude"])) == float and type(office["longitude"]) == float:
                return ({
                    "type":"Point",
                    "coordinates":[office["longitude"],office["latitude"]]
                },"success")
            else:
                return(None,"Invalid lat lat and long")
        else:
            return (None,"No lat and long keys in office dict")
    return (None,"No office")

# %%
cleaned_offices = companydata.apply(officeToGeoPoint,axis=1, result_type="expand")
cleaned_offices.columns = ["office","clean_state"]

cleaned_offices
# Out:
#                                                   office clean_state
# 0      {'type': 'Point', 'coordinates': [-121.904945,...     success
# 1      {'type': 'Point', 'coordinates': [-122.394523,...     success
# 2      {'type': 'Point', 'coordinates': [-121.904945,...     success
# 3      {'type': 'Point', 'coordinates': [-122.333253,...     success
# 3      {'type': 'Point', 'coordinates': [-73.9964312,...     success
# ...                                                  ...         ...
# 18796  {'type': 'Point', 'coordinates': [8.4371634, 4...     success
# 18797                                               None   No office
# 18798  {'type': 'Point', 'coordinates': [-74.3235539,...     success
# 18799  {'type': 'Point', 'coordinates': [-86.816068, ...     success
# 18800  {'type': 'Point', 'coordinates': [-86.7613019,...     success
#
# [21762 rows x 2 columns]

# %%
company_processed = pd.concat([companydata,cleaned_offices], axis=1)

# %%
company_processed = company_processed[["name","category_code","office","clean_state"]]

# %%
company_processed
# Out:
#                       name category_code  \
# 0                AdventNet    enterprise
# 1                     Digg          news
# 2                     Zoho      software
# 3                 Wetpaint           web
# 3                 Wetpaint           web
# ...                    ...           ...
# 18796               Oriact      software
# 18797          goBookmaker           web
# 18798           AfterLogic      software
# 18799  EnteGreat Solutions      software
# 18800            EnteGreat    enterprise
#
#                                                   office clean_state
# 0      {'type': 'Point', 'coordinates': [-121.904945,...     success
# 1      {'type': 'Point', 'coordinates': [-122.394523,...     success
# 2      {'type': 'Point', 'coordinates': [-121.904945,...     success
# 3      {'type': 'Point', 'coordinates': [-122.333253,...     success
# 3      {'type': 'Point', 'coordinates': [-73.9964312,...     success
# ...                                                  ...         ...
# 18796  {'type': 'Point', 'coordinates': [8.4371634, 4...     success
# 18797                                               None   No office
# 18798  {'type': 'Point', 'coordinates': [-74.3235539,...     success
# 18799  {'type': 'Point', 'coordinates': [-86.816068, ...     success
# 18800  {'type': 'Point', 'coordinates': [-86.7613019,...     success
#
# [21762 rows x 4 columns]

# %%
company_processed.clean_state.value_counts()
# Out:
# success                     10834
# Invalid lat lat and long     5871
# No office                    5057
# Name: clean_state, dtype: int64

# %%
# Export as json to do mongodb import
# $ mongoimport --db datamad0320 --collection companies_prepared --jsonArray companies_clean.json
company_processed.to_json("data/companies_clean.json",orient="records")

# %% [markdown]
# ## Query mongodb database with `$where` operator

# %%
def getOfficeNear(address, maxDist=1000):
    point = geocode(address)
    return {
       "office": {
         "$near": {
           "$geometry": point,
           "$maxDistance": maxDist,
         }
       }
    }

# %%
query = getOfficeNear("Times Square New York")
query
# Out:
# <Response [200]>
# {'office': {'$near': {'$geometry': {'type': 'Point',
#     'coordinates': [-73.98964, 40.75677]},
#    '$maxDistance': 1000}}}

# %%
cur = db.companies_prepared.find(query, {"_id":0})
print(cur.count())
result = list(cur)
result
# Out:
# 183
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
# [{'name': 'Real Time Content',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.990286, 40.755959]},
#   'clean_state': 'success'},
#  {'name': 'ideeli',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.990396, 40.755978]},
#   'clean_state': 'success'},
#  {'name': 'Magnetic',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.990152, 40.758343]},
#   'clean_state': 'success'},
#  {'name': 'MindSmack',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.989987, 40.758492]},
#   'clean_state': 'success'},
#  {'name': 'MYSTYLEPOST',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.989622, 40.754901]},
#   'clean_state': 'success'},
#  {'name': 'Thomson Reuters',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.9871847, 40.7564318]},
#   'clean_state': 'success'},
#  {'name': 'Thomson Reuters',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.9871847, 40.7564318]},
#   'clean_state': 'success'},
#  {'name': 'XB Labs',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.991605, 40.755329]},
#   'clean_state': 'success'},
#  {'name': 'Papervitamins',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Livekick',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'bTrendie',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Primospot',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Fotohoo',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Palyon Medical',
#   'category_code': 'biotech',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'famebook',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'artandseek',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Dragonfly',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'CPower',
#   'category_code': 'cleantech',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Conversition',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Pictela',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Papervitamins',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'The Talk Market',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'VSC Consulting',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'artandseek',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Muckety',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Wee Web',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Healism',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Hirshorn Zuckerman Design Group',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'UniversityJunction',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'PlaceVine',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'RefSeek',
#   'category_code': 'search',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Arisey',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Medialets',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Odiogo',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Delivr',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Yoostar',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'People Capital',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'GameGround',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Udorse',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986951, 40.756054]},
#   'clean_state': 'success'},
#  {'name': 'Unicast',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.988834, 40.754699]},
#   'clean_state': 'success'},
#  {'name': 'Catalyst Resources',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.986941, 40.75604]},
#   'clean_state': 'success'},
#  {'name': 'ShopMyCloset',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.986941, 40.75604]},
#   'clean_state': 'success'},
#  {'name': 'My Damn Channel',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.988543, 40.754762]},
#   'clean_state': 'success'},
#  {'name': 'Admeld',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.992152, 40.755253]},
#   'clean_state': 'success'},
#  {'name': 'TravelCLICK',
#   'category_code': 'hospitality',
#   'office': {'type': 'Point', 'coordinates': [-73.9868495, 40.755437]},
#   'clean_state': 'success'},
#  {'name': 'CPXi',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9869523, 40.7550708]},
#   'clean_state': 'success'},
#  {'name': 'Wakozi',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.992706, 40.755409]},
#   'clean_state': 'success'},
#  {'name': 'Tech Support 4 NYC',
#   'category_code': 'consulting',
#   'office': {'type': 'Point', 'coordinates': [-73.9883596, 40.754142]},
#   'clean_state': 'success'},
#  {'name': 'Zoomabet',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.992152, 40.754698]},
#   'clean_state': 'success'},
#  {'name': 'Xanga',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.992152, 40.754698]},
#   'clean_state': 'success'},
#  {'name': 'MyPRGenie',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.986005, 40.757375]},
#   'clean_state': 'success'},
#  {'name': 'Viacom',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986011, 40.757725]},
#   'clean_state': 'success'},
#  {'name': 'MTV Networks',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.986011, 40.757725]},
#   'clean_state': 'success'},
#  {'name': 'Finsbury Solutions',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.992193, 40.75451]},
#   'clean_state': 'success'},
#  {'name': 'NEHST Studios',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.992193, 40.75451]},
#   'clean_state': 'success'},
#  {'name': 'Paramount Pictures',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.9858165, 40.7577017]},
#   'clean_state': 'success'},
#  {'name': 'AdSide',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]},
#   'clean_state': 'success'},
#  {'name': 'Facilitas',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]},
#   'clean_state': 'success'},
#  {'name': 'AdSide',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.991123, 40.753931]},
#   'clean_state': 'success'},
#  {'name': 'Ladies Who Launch',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.991512, 40.753877]},
#   'clean_state': 'success'},
#  {'name': 'Kiwibox',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9935, 40.755243]},
#   'clean_state': 'success'},
#  {'name': 'Wiredset',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Propertyqube',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Wists',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'RiverWired',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'TableXchange',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Grey Global Group',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Blog Talk Radio',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'HyperCalc',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'ConcertAttack',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Clipmarks',
#   'category_code': 'photo_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Lyquidity',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'UpNext',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Fotolog',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Upshot Interactive',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Tacoda',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Outbrain',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Kidmondo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Massify',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Pinch Media',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'PeekYou',
#   'category_code': 'search',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Blogio',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Gawker Media',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Jango',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'iVillage',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Chictini',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'MeetMoi',
#   'category_code': 'social',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': '1938 Media',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Totspot',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'MyBloop',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'SnapVillage',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Gamers Media',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'revlayer',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Reuters',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Camlink',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985506, 40.757929]},
#   'clean_state': 'success'},
#  {'name': 'Epic Advertising',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.989189, 40.753403]},
#   'clean_state': 'success'},
#  {'name': 'Heavy',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.98962, 40.753385]},
#   'clean_state': 'success'},
#  {'name': 'OpTier',
#   'category_code': 'analytics',
#   'office': {'type': 'Point', 'coordinates': [-73.985647, 40.754937]},
#   'clean_state': 'success'},
#  {'name': 'yoonew',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986557, 40.75362]},
#   'clean_state': 'success'},
#  {'name': 'Flugpo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.990557, 40.752898]},
#   'clean_state': 'success'},
#  {'name': 'LineUpNewYork',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.986771, 40.753202]},
#   'clean_state': 'success'},
#  {'name': 'Jambo Media',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.98594, 40.753652]},
#   'clean_state': 'success'},
#  {'name': 'Eastmedia',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.988676, 40.752409]},
#   'clean_state': 'success'},
#  {'name': 'PEX Card',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.987871, 40.752539]},
#   'clean_state': 'success'},
#  {'name': 'Oddcast',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.988477, 40.752325]},
#   'clean_state': 'success'},
#  {'name': 'Salesconx',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.98459, 40.759243]},
#   'clean_state': 'success'},
#  {'name': 'Social Sauce',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.990675, 40.752143]},
#   'clean_state': 'success'},
#  {'name': 'Genesiz',
#   'category_code': 'ecommerce',
#   'office': {'type': 'Point', 'coordinates': [-73.990675, 40.752143]},
#   'clean_state': 'success'},
#  {'name': 'LivePerson',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.99031, 40.751969]},
#   'clean_state': 'success'},
#  {'name': 'Stream57',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.99031, 40.751969]},
#   'clean_state': 'success'},
#  {'name': 'TradingUp Online',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.992544, 40.752404]},
#   'clean_state': 'success'},
#  {'name': 'ScienCentral',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.99211, 40.752224]},
#   'clean_state': 'success'},
#  {'name': 'Veotag',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.98546, 40.752957]},
#   'clean_state': 'success'},
#  {'name': 'SeeToo',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.996272, 40.755861]},
#   'clean_state': 'success'},
#  {'name': 'Optimum Energy',
#   'category_code': 'cleantech',
#   'office': {'type': 'Point', 'coordinates': [-73.9875922, 40.7518919]},
#   'clean_state': 'success'},
#  {'name': 'Coleman Research Group',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.985025, 40.752953]},
#   'clean_state': 'success'},
#  {'name': 'Giant Realm',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9827553, 40.7566658]},
#   'clean_state': 'success'},
#  {'name': 'Lotame',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.995487, 40.753631]},
#   'clean_state': 'success'},
#  {'name': 'OgilvyOne',
#   'category_code': 'consulting',
#   'office': {'type': 'Point', 'coordinates': [-73.98749, 40.762052]},
#   'clean_state': 'success'},
#  {'name': 'Interpublic Group',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.982666, 40.754683]},
#   'clean_state': 'success'},
#  {'name': 'Wall Street Journal',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.9824129, 40.7587059]},
#   'clean_state': 'success'},
#  {'name': 'Petciety',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.995886, 40.753207]},
#   'clean_state': 'success'},
#  {'name': 'Petciety',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.995886, 40.753207]},
#   'clean_state': 'success'},
#  {'name': 'HR Integrations',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.994785, 40.752078]},
#   'clean_state': 'success'},
#  {'name': 'WeMix',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9815358, 40.7554379]},
#   'clean_state': 'success'},
#  {'name': 'Dada Entertainment',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.981847, 40.7543]},
#   'clean_state': 'success'},
#  {'name': 'Upoc',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.981847, 40.7543]},
#   'clean_state': 'success'},
#  {'name': 'Dada Entertainment',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.981847, 40.7543]},
#   'clean_state': 'success'},
#  {'name': 'KickApps',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.9843328, 40.7516611]},
#   'clean_state': 'success'},
#  {'name': 'Simparel',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]},
#   'clean_state': 'success'},
#  {'name': 'Fotki',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]},
#   'clean_state': 'success'},
#  {'name': 'Converseon',
#   'category_code': 'consulting',
#   'office': {'type': 'Point', 'coordinates': [-73.985833, 40.750823]},
#   'clean_state': 'success'},
#  {'name': 'Cellfish',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.983754, 40.761855]},
#   'clean_state': 'success'},
#  {'name': 'Connectiva Systems',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.980861, 40.755531]},
#   'clean_state': 'success'},
#  {'name': 'Deloitte',
#   'category_code': 'consulting',
#   'office': {'type': 'Point', 'coordinates': [-73.9837603, 40.7618675]},
#   'clean_state': 'success'},
#  {'name': 'Odeo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]},
#   'clean_state': 'success'},
#  {'name': 'Behind the Burner',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.981237, 40.753918]},
#   'clean_state': 'success'},
#  {'name': 'YEAONAY',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9952442, 40.751234]},
#   'clean_state': 'success'},
#  {'name': 'Altaine',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.987977, 40.749884]},
#   'clean_state': 'success'},
#  {'name': 'Crispy Gamer',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.985273, 40.750597]},
#   'clean_state': 'success'},
#  {'name': 'Peer39',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.980246, 40.755446]},
#   'clean_state': 'success'},
#  {'name': 'Meck Technology',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.99726, 40.76126]},
#   'clean_state': 'success'},
#  {'name': 'LogLogic',
#   'category_code': 'security',
#   'office': {'type': 'Point', 'coordinates': [-73.9916486, 40.749577]},
#   'clean_state': 'success'},
#  {'name': 'Relegence',
#   'category_code': 'search',
#   'office': {'type': 'Point', 'coordinates': [-73.9916617, 40.7495594]},
#   'clean_state': 'success'},
#  {'name': 'CollegeClickTV',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.9916617, 40.7495594]},
#   'clean_state': 'success'},
#  {'name': 'American Higher Education Development',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.991662, 40.749559]},
#   'clean_state': 'success'},
#  {'name': 'DreamFace Interactive',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.980737, 40.7537339]},
#   'clean_state': 'success'},
#  {'name': 'F5 Networks',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.998135, 40.75304]},
#   'clean_state': 'success'},
#  {'name': 'Velocix',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.980068, 40.758504]},
#   'clean_state': 'success'},
#  {'name': 'Associated Press',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.998615, 40.7535]},
#   'clean_state': 'success'},
#  {'name': 'Visible World',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.999003, 40.75406]},
#   'clean_state': 'success'},
#  {'name': '33Across',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.999003, 40.75406]},
#   'clean_state': 'success'},
#  {'name': 'GoLark',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.996122, 40.7508]},
#   'clean_state': 'success'},
#  {'name': 'Unigo',
#   'category_code': 'education',
#   'office': {'type': 'Point', 'coordinates': [-73.9793465, 40.7568493]},
#   'clean_state': 'success'},
#  {'name': 'Facebook',
#   'category_code': 'social',
#   'office': {'type': 'Point', 'coordinates': [-73.9792469, 40.7557162]},
#   'clean_state': 'success'},
#  {'name': 'ArtNeighbor',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9918181, 40.7489381]},
#   'clean_state': 'success'},
#  {'name': 'Strategist News',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9918181, 40.7489381]},
#   'clean_state': 'success'},
#  {'name': 'SpaceTime',
#   'category_code': None,
#   'office': {'type': 'Point', 'coordinates': [-73.979038, 40.756662]},
#   'clean_state': 'success'},
#  {'name': 'Marvel Entertainment',
#   'category_code': 'games_video',
#   'office': {'type': 'Point', 'coordinates': [-73.982713, 40.750576]},
#   'clean_state': 'success'},
#  {'name': 'Synesis IT',
#   'category_code': 'consulting',
#   'office': {'type': 'Point', 'coordinates': [-73.987106, 40.748873]},
#   'clean_state': 'success'},
#  {'name': 'Adknowledge',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.992463, 40.748901]},
#   'clean_state': 'success'},
#  {'name': 'Terra-Gen Power',
#   'category_code': 'cleantech',
#   'office': {'type': 'Point', 'coordinates': [-73.9788753, 40.7562295]},
#   'clean_state': 'success'},
#  {'name': 'TheMarkets',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.9821315, 40.762674]},
#   'clean_state': 'success'},
#  {'name': 'Scanbuy',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.9815333, 40.7512062]},
#   'clean_state': 'success'},
#  {'name': 'BountyJobs',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.97917, 40.754211]},
#   'clean_state': 'success'},
#  {'name': 'Workbridge Associates',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.9789451, 40.7543489]},
#   'clean_state': 'success'},
#  {'name': 'Napier Partners',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.9789451, 40.7543489]},
#   'clean_state': 'success'},
#  {'name': 'MacArthur Associates',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.9789451, 40.7543489]},
#   'clean_state': 'success'},
#  {'name': 'Atlantis Partners',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.9789451, 40.7543489]},
#   'clean_state': 'success'},
#  {'name': 'IrishCentral',
#   'category_code': 'public_relations',
#   'office': {'type': 'Point', 'coordinates': [-73.989276, 40.74828]},
#   'clean_state': 'success'},
#  {'name': 'Springo',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.978432, 40.758062]},
#   'clean_state': 'success'},
#  {'name': 'Unisfair',
#   'category_code': 'enterprise',
#   'office': {'type': 'Point', 'coordinates': [-73.988154, 40.7482]},
#   'clean_state': 'success'},
#  {'name': 'LucidMedia',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.980739, 40.751336]},
#   'clean_state': 'success'},
#  {'name': 'TxVia',
#   'category_code': 'finance',
#   'office': {'type': 'Point', 'coordinates': [-73.978852, 40.753881]},
#   'clean_state': 'success'},
#  {'name': 'TMP Directional Marketing',
#   'category_code': 'advertising',
#   'office': {'type': 'Point', 'coordinates': [-73.9790822, 40.7530803]},
#   'clean_state': 'success'},
#  {'name': 'Jumptap',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.980305, 40.751478]},
#   'clean_state': 'success'},
#  {'name': 'Jumptap',
#   'category_code': 'mobile',
#   'office': {'type': 'Point', 'coordinates': [-73.980305, 40.751478]},
#   'clean_state': 'success'},
#  {'name': 'BarterQuest',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.994203, 40.748634]},
#   'clean_state': 'success'},
#  {'name': 'Aleri',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.9783534, 40.7592189]},
#   'clean_state': 'success'},
#  {'name': 'Warner Music Group',
#   'category_code': 'other',
#   'office': {'type': 'Point', 'coordinates': [-73.9783534, 40.7592189]},
#   'clean_state': 'success'},
#  {'name': 'SheZoom',
#   'category_code': 'network_hosting',
#   'office': {'type': 'Point', 'coordinates': [-73.9785086, 40.7538639]},
#   'clean_state': 'success'},
#  {'name': 'Social Median',
#   'category_code': 'web',
#   'office': {'type': 'Point', 'coordinates': [-73.982575, 40.74963]},
#   'clean_state': 'success'},
#  {'name': 'RankAbove',
#   'category_code': 'software',
#   'office': {'type': 'Point', 'coordinates': [-73.992402, 40.748047]},
#   'clean_state': 'success'}]

# %%
def easyLatLng(row):
    of = row.office
    return {
        "latitude":of["coordinates"][1],
        "longitude":of["coordinates"][0]
    }

# https://api.mongodb.com/python/current/api/bson/objectid.html
df = pd.DataFrame(result)

df = pd.concat([df, df.apply(easyLatLng, axis=1, result_type="expand")], axis=1)
df
# Out:
#                    name    category_code  \
# 0     Real Time Content      advertising
# 1                ideeli        ecommerce
# 2              Magnetic      advertising
# 3             MindSmack      games_video
# 4           MYSTYLEPOST  network_hosting
# ..                  ...              ...
# 178               Aleri         software
# 179  Warner Music Group            other
# 180             SheZoom  network_hosting
# 181       Social Median              web
# 182           RankAbove         software
#
#                                                 office clean_state   latitude  \
# 0    {'type': 'Point', 'coordinates': [-73.990286, ...     success  40.755959
# 1    {'type': 'Point', 'coordinates': [-73.990396, ...     success  40.755978
# 2    {'type': 'Point', 'coordinates': [-73.990152, ...     success  40.758343
# 3    {'type': 'Point', 'coordinates': [-73.989987, ...     success  40.758492
# 4    {'type': 'Point', 'coordinates': [-73.989622, ...     success  40.754901
# ..                                                 ...         ...        ...
# 178  {'type': 'Point', 'coordinates': [-73.9783534,...     success  40.759219
# 179  {'type': 'Point', 'coordinates': [-73.9783534,...     success  40.759219
# 180  {'type': 'Point', 'coordinates': [-73.9785086,...     success  40.753864
# 181  {'type': 'Point', 'coordinates': [-73.982575, ...     success  40.749630
# 182  {'type': 'Point', 'coordinates': [-73.992402, ...     success  40.748047
#
#      longitude
# 0   -73.990286
# 1   -73.990396
# 2   -73.990152
# 3   -73.989987
# 4   -73.989622
# ..         ...
# 178 -73.978353
# 179 -73.978353
# 180 -73.978509
# 181 -73.982575
# 182 -73.992402
#
# [183 rows x 6 columns]

# %%
df.to_json("data/query_ts.json",orient="records")

# %%
# https://python-visualization.github.io/folium/
# https://carto.com/developers/cartoframes/
