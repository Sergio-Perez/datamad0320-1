# %%
from PIL import Image
import numpy as np
im = Image.open("data/bart.jpg")
imarr = np.array(im)

# %%
imarr.shape
# Out:
# (300, 300, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(imarr)

# %%
imgbw = np.array(im.convert("L"))
print(imgbw.shape)
plt.imshow(imgbw, cmap="gray")
# Out:
# (300, 300)

# %%
cara = imgbw[0:150,100:200]
plt.imshow(cara, cmap="gray")

# %%
mask = np.ones(imgbw.shape)
mask[0:150,100:200] = 0
plt.imshow(mask, cmap="gray")

# %%
plt.imshow(mask*imgbw, cmap="gray")
